# %% [markdown]
# # 📈 Stock Forecasting Pipeline using XGBoost with Financial Report Injection
#
# This pipeline predicts future stock prices for Israeli companies by combining historical price features with quarterly financial report-based metrics. It trains and saves a separate XGBoost model per ticker, using:
#
# - Rolling technical indicators (mean, std, median).
# - Injected financial report correlations (net income, revenue, total assets).
# - Stochastic future price simulation for 30-day forecasts.
#
# ## 💡 Key Components
# - `generate_report_dates(year)`: Generates quarterly financial dates.
# - Financial injection includes:
#   - Metric correlations
#   - Price changes
#   - Score deltas (model-based scores)
# - Standardized `X_train`, `X_test` using `StandardScaler`.
# - Chronological train-test split.
# - Forecasts future prices with sampled % changes based on model output volatility.
#
# ## 📤 Outputs
# - Trained `.pkl` model per stock.
# - CSV with evaluation metrics and 30-day forecast per ticker.
# - Handles edge cases with zero imputation and forward-filling logic.
#
# ## 🧠 Evaluation Metrics
# - **R-squared**
# - **MAE**
# - **MSE**
# - **MAPE**

# %% [markdown]
# ### Mounting drive:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Downloading data:

# %%
# =========================
# 📆 XGBoost Pipeline with Report Parameter Injection
# =========================
import os
import json
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from xgboost import XGBRegressor
import pickle
import warnings
warnings.filterwarnings("ignore")

# =========================
# 📚 Helper Functions
# =========================
def generate_report_dates(year):
    return [
        pd.Timestamp(f"{year}-03-31"),
        pd.Timestamp(f"{year}-06-30"),
        pd.Timestamp(f"{year}-09-30"),
        pd.Timestamp(f"{year}-12-31")
    ]

# =========================
# 🔥 Load and Preprocess Stock Data
# =========================
df_tickers = pd.read_csv("/content/drive/Shareddrives/capstone project-stock market robo-advisor/symbols_Israel.csv")
tickers = df_tickers["0"].dropna().tolist()

# Download stock data
raw_data = yf.download(tickers, start="2020-01-01", end="2024-12-31", auto_adjust=False)['Close']

# Feature Engineering
for window in [2, 5, 10, 20, 60]:
    for ticker in tickers:
        raw_data[f'{ticker}_rolling_{window}'] = raw_data[ticker].rolling(window=window).mean()
        raw_data[f'{ticker}_rollingSTD_{window}'] = raw_data[ticker].rolling(window=window).std()
        raw_data[f'{ticker}_rollingMedian_{window}'] = raw_data[ticker].rolling(window=window).median()

raw_data = raw_data.fillna(method='ffill').fillna(method='bfill')

# =========================
# 📊 Initialize Outputs
# =========================
metrics_df = pd.DataFrame()
save_dir = "/content/drive/Shareddrives/capstone project-stock market robo-advisor/XGBoost models with report parameters"
os.makedirs(save_dir, exist_ok=True)
# Out:
# [**********************50%                       ]  255 of 510 completedERROR:yfinance:Could not get exchangeTimezoneName for ticker '???.TA' reason: 'chart'
# [*********************100%***********************]  510 of 510 completed
# ERROR:yfinance:
# 15 Failed downloads:
# ERROR:yfinance:['UNVO.TA', 'ARAD.TA', 'LVPR.TA', 'AICS-M.TA', 'CNZN.TA', '???.TA', 'INFR-M.TA', 'HDHA.TA', 'PMCN.TA', 'ENDY.TA', 'INTO.TA', 'ECPA-M.TA', 'UNCR.TA', 'GLTC.TA', 'YAAC.TA']: YFTzMissingError('possibly delisted; no timezone found')

# %% [markdown]
# ### Models Training & saving:

# %%
# =========================
# ⏳ Loop Over Tickers
# =========================
for ticker in tickers:
    try:
        print(f"\n================ Processing {ticker} ================")

        # -------------------------
        # 🌐 Financial Parameters Injection
        # -------------------------
        metrics_features = ['Net Income', 'Total Assets', 'Revenue']
        financial_dates = []
        for y in range(2020, 2025):
            financial_dates.extend(generate_report_dates(y))

        financial_features = pd.DataFrame(0.0, index=raw_data.index, columns=[
            f'{feature}_metrics_change' for feature in metrics_features] +
            [f'{feature}_price_change_last_day' for feature in metrics_features] +
            [f'{feature}_price_change_30d' for feature in metrics_features] +
            [f'{feature}_price_change_90d' for feature in metrics_features] +
            [f'{feature}_score_last_day' for feature in metrics_features] +
            [f'{feature}_score_30d' for feature in metrics_features] +
            [f'{feature}_score_90d' for feature in metrics_features]
        )

        for date in pd.to_datetime(financial_dates):
            try:
                year = date.year if date.month != 3 or date.year == 2020 else date.year - 1
                quarter = ('Q1' if date.month == 3 else 'Q2' if date.month == 6 else 'Q3' if date.month == 9 else 'Q4')
                next_quarter = ('Q2' if quarter == 'Q1' else 'Q3' if quarter == 'Q2' else 'Q4' if quarter == 'Q3' else 'Q1')
                next_year = year if quarter != 'Q4' else year + 1
                if next_year > 2024:
                    continue

                base_path = "/content/drive/Shareddrives/capstone project-stock market robo-advisor/Reports Parameters/Correlations"
                metrics_path = f"{base_path}/correlation metrics change/{quarter}_{year}_to_{next_quarter}_{next_year}.csv"
                price_change_path = f"{base_path}/correlations price change/{quarter}_{year}_to_{next_quarter}_{next_year}.csv"
                score_path = f"{base_path}/correlation score/{quarter}_{year}_to_{next_quarter}_{next_year}.csv"

                cmc = pd.read_csv(metrics_path, index_col=0)
                cpc = pd.read_csv(price_change_path, index_col=0)
                cs = pd.read_csv(score_path, index_col=0)

                if date not in financial_features.index:
                    continue

                for feature in metrics_features:
                    if ticker in cmc.index:
                        val = cmc.loc[ticker, feature]
                        val_list_price = eval(cpc.loc[ticker, feature])
                        val_list_score = eval(cs.loc[ticker, feature])
                    else:
                        val = 0
                        val_list_price = [0, 0, 0]
                        val_list_score = [0, 0, 0]

                    financial_features.at[date, f'{feature}_metrics_change'] = val
                    financial_features.at[date, f'{feature}_price_change_last_day'] = val_list_price[0]
                    financial_features.at[date, f'{feature}_price_change_30d'] = val_list_price[1]
                    financial_features.at[date, f'{feature}_price_change_90d'] = val_list_price[2]
                    financial_features.at[date, f'{feature}_score_last_day'] = val_list_score[0]
                    financial_features.at[date, f'{feature}_score_30d'] = val_list_score[1]
                    financial_features.at[date, f'{feature}_score_90d'] = val_list_score[2]

            except Exception as e:
                print(f"Skipping financials for {date.date()}: {e}")

        def ffill_nonzero(df):
            for col in df.columns:
                last_val = None
                for idx in df.index:
                    if df.at[idx, col] != 0.0:
                        last_val = df.at[idx, col]
                    elif last_val is not None:
                        df.at[idx, col] = last_val
            return df

        financial_features = ffill_nonzero(financial_features)
        raw_data = raw_data.dropna(axis=1, how='all')

        # -------------------------
        # 🔹 Combine All Features
        # -------------------------
        full_df = pd.concat([raw_data, financial_features], axis=1).dropna()
        if ticker not in full_df.columns:
            continue

        y = full_df[ticker]
        X = full_df.drop(columns=[ticker])

        scaler = StandardScaler()
        X_scaled = pd.DataFrame(scaler.fit_transform(X), index=X.index, columns=X.columns)

        # Chronological train-test split
        X_train, X_test, y_train, y_test = train_test_split(
            X_scaled, y, test_size=0.2, shuffle=False
        )

        # Train model
        model = XGBRegressor(n_estimators=100, learning_rate=0.05, max_depth=6, random_state=42)
        model.fit(X_train, y_train)

        # Evaluate
        y_pred = model.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        mae = mean_absolute_error(y_test, y_pred)
        mse = mean_squared_error(y_test, y_pred)
        mape = mean_absolute_percentage_error(y_test, y_pred)

        # Forecast future prices
        future_pred = [y_pred[-1]]
        for _ in range(30):
            pct_changes = pd.Series(y_pred).pct_change().dropna()
            mean_pct = pct_changes.mean()
            std_pct = pct_changes.std()
            future_pred.append(future_pred[-1] * (1 + np.random.normal(mean_pct, std_pct)))
            y_pred.append(future_pred[-1])
        y_pred = y_pred[:-30]
        future_pred = future_pred[1:]

        forecast_columns = {f"Day_{i+1}": future_pred[i] for i in range(30)}
        metrics_data = {
            "Stock": ticker,
            "R-squared": r2,
            "MAE": mae,
            "MSE": mse,
            "MAPE": mape,
            **forecast_columns,
            "y_test": json.dumps(y_test.tolist()),
            "y_pred": json.dumps(y_pred.tolist())
        }
        metrics_df = pd.concat([metrics_df, pd.DataFrame([metrics_data])], ignore_index=True)

        # Save model
        model_path = os.path.join(save_dir, f"{ticker.replace('.', '_')}_XGBoost_model.pkl")
        with open(model_path, 'wb') as f:
            pickle.dump(model, f)

        print(f"✅ {ticker} saved. R2: {r2:.4f}, MAE: {mae:.2f}, MAPE: {mape:.2f}, MSE: {mse:.2f}")

    except Exception as e:
        print(f"❌ Failed {ticker}: {e}")

# Save final CSV
metrics_df.to_csv(os.path.join(save_dir, "metrics_xgboost_with_report_parameters.csv"), index=False)
print("\n📅 All stocks processed.")
# Out:
# ================ Processing REKA.TA ================
# ✅ REKA.TA saved. R2: -2.3001, MAE: 128.84, MAPE: 0.10, MSE: 22808.41
#
# ================ Processing RTMD-L.TA ================
# ✅ RTMD-L.TA saved. R2: -3.6934, MAE: 49.83, MAPE: 0.87, MSE: 3130.55
#
# ================ Processing RTLS.TA ================
# ✅ RTLS.TA saved. R2: 0.9618, MAE: 124.54, MAPE: 0.02, MSE: 34137.29
#
# ================ Processing RMON.TA ================
# ✅ RMON.TA saved. R2: 0.9887, MAE: 38.69, MAPE: 0.01, MSE: 2557.43
#
# ================ Processing RIMO.TA ================
# ✅ RIMO.TA saved. R2: 0.8770, MAE: 135.02, MAPE: 0.03, MSE: 28804.46
#
# ================ Processing ROBO.TA ================
# ✅ ROBO.TA saved. R2: 0.8345, MAE: 5.49, MAPE: 0.05, MSE: 53.24
#
# ================ Processing RTEN.TA ================
# ✅ RTEN.TA saved. R2: 0.7099, MAE: 5.22, MAPE: 0.01, MSE: 48.01
#
# ================ Processing ROTS.TA ================
# ✅ ROTS.TA saved. R2: 0.9082, MAE: 125.00, MAPE: 0.02, MSE: 63603.00
#
# ================ Processing RSEL.TA ================
# ✅ RSEL.TA saved. R2: 0.9326, MAE: 9.09, MAPE: 0.02, MSE: 159.42
#
# ================ Processing SRAC.TA ================
# ✅ SRAC.TA saved. R2: 0.8745, MAE: 137.50, MAPE: 0.05, MSE: 24220.78
#
# ================ Processing SANO1.TA ================
# ✅ SANO1.TA saved. R2: 0.9693, MAE: 294.66, MAPE: 0.01, MSE: 162060.87
#
# ================ Processing SPNS.TA ================
# ✅ SPNS.TA saved. R2: 0.0705, MAE: 996.71, MAPE: 0.07, MSE: 2017872.78
#
# ================ Processing SRFT.TA ================
# ✅ SRFT.TA saved. R2: 0.0409, MAE: 246.88, MAPE: 0.07, MSE: 166512.23
#
# ================ Processing SARN.TA ================
# ✅ SARN.TA saved. R2: -3.0501, MAE: 12.27, MAPE: 0.18, MSE: 201.86
#
# ================ Processing SVRE.TA ================
# ✅ SVRE.TA saved. R2: -1.9559, MAE: 619.40, MAPE: 1.79, MSE: 529461.02
#
# ================ Processing SVRT.TA ================
# ✅ SVRT.TA saved. R2: -9.6446, MAE: 453.01, MAPE: 0.54, MSE: 242333.12
#
# ================ Processing SHNP.TA ================
# ✅ SHNP.TA saved. R2: 0.7854, MAE: 57.44, MAPE: 0.05, MSE: 3926.68
#
# ================ Processing SCDX.TA ================
# ✅ SCDX.TA saved. R2: -0.2792, MAE: 19.69, MAPE: 0.08, MSE: 902.89
#
# ================ Processing SCOP.TA ================
# ✅ SCOP.TA saved. R2: 0.9599, MAE: 189.16, MAPE: 0.02, MSE: 56442.08
#
# ================ Processing SEMG.TA ================
# ✅ SEMG.TA saved. R2: 0.1801, MAE: 37.68, MAPE: 0.22, MSE: 1877.90
#
# ================ Processing SLARL.TA ================
# ✅ SLARL.TA saved. R2: 0.9808, MAE: 8.62, MAPE: 0.01, MSE: 131.66
#
# ================ Processing SHGR.TA ================
# ✅ SHGR.TA saved. R2: 0.7776, MAE: 47.73, MAPE: 0.05, MSE: 3474.08
#
# ================ Processing SHMM.TA ================
# ✅ SHMM.TA saved. R2: -1.7448, MAE: 35.98, MAPE: 1.79, MSE: 1684.59
#
# ================ Processing SHAN.TA ================
# ✅ SHAN.TA saved. R2: 0.8190, MAE: 9.30, MAPE: 0.03, MSE: 149.11
#
# ================ Processing SPEN.TA ================
# ✅ SPEN.TA saved. R2: 0.9342, MAE: 49.22, MAPE: 0.02, MSE: 5374.26
#
# ================ Processing SMNR.TA ================
# ✅ SMNR.TA saved. R2: 0.9680, MAE: 37.61, MAPE: 0.02, MSE: 2470.34
#
# ================ Processing SBEN.TA ================
# ✅ SBEN.TA saved. R2: 0.6247, MAE: 7.66, MAPE: 0.03, MSE: 154.73
#
# ================ Processing SKBN.TA ================
# ✅ SKBN.TA saved. R2: 0.9557, MAE: 25.49, MAPE: 0.03, MSE: 1383.40
#
# ================ Processing SHOM.TA ================
# ✅ SHOM.TA saved. R2: 0.8478, MAE: 11.62, MAPE: 0.01, MSE: 233.69
#
# ================ Processing SAE.TA ================
# ✅ SAE.TA saved. R2: 0.7339, MAE: 210.16, MAPE: 0.06, MSE: 131794.37
#
# ================ Processing SKLN.TA ================
# ✅ SKLN.TA saved. R2: 0.8157, MAE: 72.21, MAPE: 0.03, MSE: 9776.92
#
# ================ Processing SLRM.TA ================
# ✅ SLRM.TA saved. R2: -0.1104, MAE: 134.18, MAPE: 0.37, MSE: 27682.06
#
# ================ Processing SMAG.TA ================
# ✅ SMAG.TA saved. R2: -3.8181, MAE: 125.25, MAPE: 0.34, MSE: 22511.72
#
# ================ Processing SOFW.TA ================
# ✅ SOFW.TA saved. R2: -10.6952, MAE: 366.05, MAPE: 0.20, MSE: 150556.12
#
# ================ Processing SOLR.TA ================
# ✅ SOLR.TA saved. R2: 0.9510, MAE: 23.54, MAPE: 0.01, MSE: 1212.65
#
# ================ Processing SONO.TA ================
# ✅ SONO.TA saved. R2: -3.5762, MAE: 134.08, MAPE: 1.21, MSE: 28891.11
#
# ================ Processing SCC.TA ================
# ✅ SCC.TA saved. R2: 0.0548, MAE: 30.30, MAPE: 0.05, MSE: 1417.76
#
# ================ Processing SPDV.TA ================
# ✅ SPDV.TA saved. R2: 0.1281, MAE: 30.32, MAPE: 0.07, MSE: 1856.81
#
# ================ Processing SPRG.TA ================
# ✅ SPRG.TA saved. R2: 0.5479, MAE: 136.95, MAPE: 0.15, MSE: 27956.81
#
# ================ Processing SPNTC.TA ================
# ✅ SPNTC.TA saved. R2: -0.2143, MAE: 33.46, MAPE: 0.07, MSE: 1649.50
#
# ================ Processing STG.TA ================
# ✅ STG.TA saved. R2: -7.1178, MAE: 516.73, MAPE: 0.12, MSE: 310724.05
#
# ================ Processing STRG.TA ================
# ✅ STRG.TA saved. R2: -6.4690, MAE: 36.18, MAPE: 0.67, MSE: 2248.65
#
# ================ Processing STRS.TA ================
# ✅ STRS.TA saved. R2: -2.0900, MAE: 896.55, MAPE: 0.15, MSE: 1099000.55
#
# ================ Processing STRW.TA ================
# ✅ STRW.TA saved. R2: -0.0701, MAE: 230.94, MAPE: 2.60, MSE: 576336.52
#
# ================ Processing SFRN.TA ================
# ✅ SFRN.TA saved. R2: 0.8405, MAE: 26.01, MAPE: 0.04, MSE: 1971.60
#
# ================ Processing SMT.TA ================
# ✅ SMT.TA saved. R2: 0.7159, MAE: 35.92, MAPE: 0.01, MSE: 1883.64
#
# ================ Processing SNFL.TA ================
# ✅ SNFL.TA saved. R2: 0.9695, MAE: 5.30, MAPE: 0.01, MSE: 46.72
#
# ================ Processing SNCM.TA ================
# ✅ SNCM.TA saved. R2: 0.9164, MAE: 1.59, MAPE: 0.01, MSE: 5.94
#
# ================ Processing STEC.TA ================
# ✅ STEC.TA saved. R2: 0.5324, MAE: 45.96, MAPE: 2.26, MSE: 10583.48
#
# ================ Processing SNEL.TA ================
# ✅ SNEL.TA saved. R2: -0.5159, MAE: 169.31, MAPE: 0.09, MSE: 65634.15
#
# ================ Processing TDRN.TA ================
# ✅ TDRN.TA saved. R2: 0.9795, MAE: 394.63, MAPE: 0.02, MSE: 277414.78
#
# ================ Processing TMRP.TA ================
# ✅ TMRP.TA saved. R2: -1.6798, MAE: 387.33, MAPE: 0.19, MSE: 216462.93
#
# ================ Processing TRA.TA ================
# ✅ TRA.TA saved. R2: -3.1524, MAE: 12.10, MAPE: 0.43, MSE: 191.43
#
# ================ Processing TATT.TA ================
# ✅ TATT.TA saved. R2: -2.4760, MAE: 2309.42, MAPE: 0.37, MSE: 7580528.04
#
# ================ Processing TAYA.TA ================
# ✅ TAYA.TA saved. R2: 0.9860, MAE: 48.44, MAPE: 0.01, MSE: 4405.30
#
# ================ Processing TNPV.TA ================
# ✅ TNPV.TA saved. R2: 0.7932, MAE: 38.45, MAPE: 0.79, MSE: 6785.63
#
# ================ Processing TECT.TA ================
# ✅ TECT.TA saved. R2: -1.0414, MAE: 51.91, MAPE: 0.33, MSE: 3111.24
#
# ================ Processing TEDE.TA ================
# ✅ TEDE.TA saved. R2: 0.0041, MAE: 158.74, MAPE: 2.13, MSE: 60129.51
#
# ================ Processing TFRLF.TA ================
# ✅ TFRLF.TA saved. R2: -1.0152, MAE: 353.36, MAPE: 0.12, MSE: 188435.40
#
# ================ Processing TLSY.TA ================
# ✅ TLSY.TA saved. R2: 0.8398, MAE: 1022.96, MAPE: 0.06, MSE: 1507365.75
#
# ================ Processing TRLT.TA ================
# ✅ TRLT.TA saved. R2: 0.7172, MAE: 34.62, MAPE: 0.05, MSE: 1523.69
#
# ================ Processing TRX.TA ================
# ✅ TRX.TA saved. R2: 0.2204, MAE: 44.18, MAPE: 0.14, MSE: 2574.86
#
# ================ Processing TUZA.TA ================
# ✅ TUZA.TA saved. R2: 0.7166, MAE: 1.93, MAPE: 0.05, MSE: 6.18
#
# ================ Processing TEVA.TA ================
# ✅ TEVA.TA saved. R2: 0.8813, MAE: 55.77, MAPE: 0.02, MSE: 5437.76
#
# ================ Processing TGI.TA ================
# ✅ TGI.TA saved. R2: 0.8065, MAE: 7.68, MAPE: 0.04, MSE: 98.82
#
# ================ Processing ILCO.TA ================
# ✅ ILCO.TA saved. R2: 0.8984, MAE: 1656.76, MAPE: 0.02, MSE: 4925932.81
#
# ================ Processing TMIS.TA ================
# ✅ TMIS.TA saved. R2: 0.9196, MAE: 31.18, MAPE: 0.03, MSE: 2160.31
#
# ================ Processing THES.TA ================
# ✅ THES.TA saved. R2: 0.5818, MAE: 29.17, MAPE: 0.05, MSE: 4191.71
#
# ================ Processing TIGBUR.TA ================
# ✅ TIGBUR.TA saved. R2: -10.7874, MAE: 1444.87, MAPE: 0.32, MSE: 2579301.39
#
# ================ Processing TIGI.TA ================
# ✅ TIGI.TA saved. R2: 0.0725, MAE: 82.72, MAPE: 0.26, MSE: 13611.90
#
# ================ Processing TKUN.TA ================
# ✅ TKUN.TA saved. R2: -43.2398, MAE: 21.28, MAPE: 0.62, MSE: 751.87
#
# ================ Processing TTAM.TA ================
# ✅ TTAM.TA saved. R2: -3.9364, MAE: 107.79, MAPE: 0.20, MSE: 13361.26
#
# ================ Processing TGTR.TA ================
# ✅ TGTR.TA saved. R2: 0.8449, MAE: 37.81, MAPE: 0.01, MSE: 2119.94
#
# ================ Processing TOEN.TA ================
# ✅ TOEN.TA saved. R2: 0.9621, MAE: 8.27, MAPE: 0.01, MSE: 95.17
#
# ================ Processing TNDO.TA ================
# ✅ TNDO.TA saved. R2: 0.9527, MAE: 19.49, MAPE: 0.03, MSE: 659.31
#
# ================ Processing TOPS.TA ================
# ✅ TOPS.TA saved. R2: 0.9828, MAE: 8.79, MAPE: 0.01, MSE: 134.54
#
# ================ Processing TSEM.TA ================
# ✅ TSEM.TA saved. R2: 0.8798, MAE: 527.79, MAPE: 0.04, MSE: 490752.72
#
# ================ Processing TRAN.TA ================
# ✅ TRAN.TA saved. R2: -0.1073, MAE: 50.60, MAPE: 1.01, MSE: 4120.69
#
# ================ Processing TSG.TA ================
# ✅ TSG.TA saved. R2: -0.4844, MAE: 818.62, MAPE: 0.06, MSE: 2049923.58
#
# ================ Processing TURB.TA ================
# ✅ TURB.TA saved. R2: -0.5302, MAE: 180.91, MAPE: 0.40, MSE: 46510.29
#
# ================ Processing TRPZ.TA ================
# ✅ TRPZ.TA saved. R2: 0.9165, MAE: 47.94, MAPE: 0.03, MSE: 3771.14
#
# ================ Processing UMH.TA ================
# ✅ UMH.TA saved. R2: -4.4995, MAE: 5062.75, MAPE: 0.83, MSE: 31263687.56
#
# ================ Processing UNCR.TA ================
#
# ================ Processing UNTC.TA ================
# ✅ UNTC.TA saved. R2: 0.2824, MAE: 32.01, MAPE: 8.71, MSE: 2993.70
#
# ================ Processing UNCT.TA ================
# ✅ UNCT.TA saved. R2: -49.1292, MAE: 51.42, MAPE: 2.10, MSE: 2669.69
#
# ================ Processing UNIT.TA ================
# ✅ UNIT.TA saved. R2: -0.1624, MAE: 382.92, MAPE: 0.11, MSE: 274520.31
#
# ================ Processing UNVO.TA ================
#
# ================ Processing UPSL.TA ================
# ✅ UPSL.TA saved. R2: -26.5084, MAE: 98.65, MAPE: 4.47, MSE: 12846.20
#
# ================ Processing UTRN.TA ================
# ✅ UTRN.TA saved. R2: -2.4237, MAE: 93.19, MAPE: 0.25, MSE: 10290.20
#
# ================ Processing VRDS.TA ================
# ✅ VRDS.TA saved. R2: 0.5896, MAE: 101.97, MAPE: 0.05, MSE: 25380.25
#
# ================ Processing VCTR.TA ================
# ✅ VCTR.TA saved. R2: -0.0152, MAE: 441.76, MAPE: 0.09, MSE: 298475.13
#
# ================ Processing VILR.TA ================
# ✅ VILR.TA saved. R2: 0.9757, MAE: 123.58, MAPE: 0.01, MSE: 25545.97
#
# ================ Processing VISN.TA ================
# ✅ VISN.TA saved. R2: 0.9911, MAE: 45.56, MAPE: 0.01, MSE: 3047.14
#
# ================ Processing VTNA.TA ================
# ✅ VTNA.TA saved. R2: 0.8989, MAE: 48.64, MAPE: 0.02, MSE: 5971.63
#
# ================ Processing WATR.TA ================
# ✅ WATR.TA saved. R2: -5.8038, MAE: 147.34, MAPE: 0.98, MSE: 24412.86
#
# ================ Processing WESR.TA ================
# ✅ WESR.TA saved. R2: 0.7932, MAE: 39.06, MAPE: 0.14, MSE: 2429.69
#
# ================ Processing WILK.TA ================
# ✅ WILK.TA saved. R2: -8.8185, MAE: 32.60, MAPE: 0.68, MSE: 1218.68
#
# ================ Processing WLFD.TA ================
# ✅ WLFD.TA saved. R2: 0.9245, MAE: 55.13, MAPE: 0.03, MSE: 4749.60
#
# ================ Processing WILC.TA ================
# ✅ WILC.TA saved. R2: -0.6794, MAE: 708.80, MAPE: 0.14, MSE: 1076316.05
#
# ================ Processing WNBZ.TA ================
# ✅ WNBZ.TA saved. R2: -0.5861, MAE: 6.52, MAPE: 0.30, MSE: 57.11
#
# ================ Processing XTLB.TA ================
# ✅ XTLB.TA saved. R2: -3.1109, MAE: 0.30, MAPE: 0.08, MSE: 0.11
#
# ================ Processing YBRD.TA ================
# ✅ YBRD.TA saved. R2: 0.4429, MAE: 368.17, MAPE: 3.37, MSE: 178350.95
#
# ================ Processing YAAC.TA ================
#
# ================ Processing YBOX.TA ================
# ✅ YBOX.TA saved. R2: 0.9814, MAE: 0.95, MAPE: 0.01, MSE: 1.75
#
# ================ Processing YHNF.TA ================
# ✅ YHNF.TA saved. R2: 0.9870, MAE: 207.53, MAPE: 0.01, MSE: 77673.55
#
# ================ Processing ZNKL.TA ================
# ✅ ZNKL.TA saved. R2: -3.6160, MAE: 916.01, MAPE: 0.26, MSE: 1072037.49
#
# ================ Processing ZPRS.TA ================
# ✅ ZPRS.TA saved. R2: 0.7237, MAE: 105.10, MAPE: 0.08, MSE: 20176.24
#
# ================ Processing ZMH.TA ================
# ✅ ZMH.TA saved. R2: 0.9750, MAE: 40.74, MAPE: 0.01, MSE: 3793.56
#
# ================ Processing ZOOZ.TA ================
# ✅ ZOOZ.TA saved. R2: -5.9666, MAE: 509.86, MAPE: 0.60, MSE: 347437.77
#
# ================ Processing ZUR.TA ================
# ✅ ZUR.TA saved. R2: 0.9582, MAE: 10.82, MAPE: 0.02, MSE: 303.47
#
# 📅 All stocks processed.

# %%
metrics_df
